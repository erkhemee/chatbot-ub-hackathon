# %%
# import our chat-bot intents file
import json
with open('intents.mn_extended.json') as json_data:
    intents = json.load(json_data)

# %%
for i in intents['intents']:
    # find a tag matching the first result
    patterns = i['patterns'];
    for pattern in patterns:
        print (pattern)
# Out:
# SCM гэж юу вэ?
# SCM гэдгийг тайлбарлаж өгнө үү?
# SCM гэдгийн талаар хэлж өгөөч?
# SCM юу вэ?
# SCM гэснийг тайлбарлаач?
# SCM тайлбарлана уу?
# SCM тайлбарла?
# SCM хэлнэ үү?
# SCM хэл?
# SCM талаар ойлгуулж өгнө үү?
# SCM талаар хэлж өгнө үү?
# SCM тайлбарлах?
# SCM гэдэг нь юу вэ?
# SCM тухай хэлж өгнө үү?
# SCM тухай тайлбарлаж өгнө үү?
# SCM гэснийг тайлбарлаж өгнө үү?
# SCM гэж яг юу вэ?
# SCM гэж юуг хэлэх вэ?
# SCM гэж яг юуг хэлэх вэ?
# SCM гэж юу болох талаар хэлж өгөөч?
# Бараа яаж бүртгэх
# Барааны төлөв гэж юу вэ
# Барааны төлөв гэдгийг тайлбарлаж өгнө үү
# Барааны төлөв гэдгийн талаар хэлж өгөөч
# Барааны төлөв юу вэ
# Барааны төлөв гэснийг тайлбарлаач
# Барааны төлөв тайлбарлана уу
# Барааны төлөв тайлбарла
# Барааны төлөв хэлнэ үү
# Барааны төлөв хэл
# Барааны төлөв талаар ойлгуулж өгнө үү
# Барааны төлөв талаар хэлж өгнө үү
# Барааны төлөв тайлбарлах
# Барааны төлөв гэдэг нь юу вэ
# Барааны төлөв тухай хэлж өгнө үү
# Барааны төлөв тухай тайлбарлаж өгнө үү
# ...
